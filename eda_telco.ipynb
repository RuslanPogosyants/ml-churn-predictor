# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/telco_churn_sample.csv')
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              1      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3  Female              0      No         No      45           No
# 4  Female              0     Yes        Yes       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No         Yes             Yes  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            10 non-null     object
#  1   SeniorCitizen     10 non-null     int64
#  2   Partner           10 non-null     object
#  3   Dependents        10 non-null     object
#  4   tenure            10 non-null     int64
#  5   PhoneService      10 non-null     object
#  6   MultipleLines     10 non-null     object
#  7   InternetService   10 non-null     object
#  8   OnlineSecurity    10 non-null     object
#  9   OnlineBackup      10 non-null     object
#  10  DeviceProtection  10 non-null     object
#  11  TechSupport       10 non-null     object
#  12  StreamingTV       10 non-null     object
#  13  StreamingMovies   10 non-null     object
#  14  Contract          10 non-null     object
#  15  PaperlessBilling  10 non-null     object
#  16  PaymentMethod     10 non-null     object
#  17  MonthlyCharges    10 non-null     float64
#  18  TotalCharges      10 non-null     float64
#  19  Churn             10 non-null     object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 1.7+ KB

# %%
df.describe()
# Out:
#        SeniorCitizen     tenure  MonthlyCharges  TotalCharges
# count      10.000000  10.000000       10.000000     10.000000
# mean        0.200000  21.400000       54.105000    857.115000
# std         0.421637  20.780333       26.154492    822.693522
# min         0.000000   1.000000       18.950000     29.850000
# 25%         0.000000   3.500000       32.962500    122.887500
# 50%         0.000000  16.000000       51.900000    561.200000
# 75%         0.000000  32.500000       67.262500   1722.100000
# max         1.000000  62.000000       99.650000   1949.400000

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# Churn
# No     0.6
# Yes    0.4
# Name: proportion, dtype: float64

# %%
sns.countplot(data=df, x='Contract', hue='Churn')
plt.title('Churn by Contract Type')
plt.xticks(rotation=45)
plt.show()

# %%
sns.histplot(data=df, x='MonthlyCharges', hue='Churn', kde=True)
plt.title('Churn by Monthly Charges')
plt.show()

# %%
sns.histplot(data=df, x='tenure', hue='Churn', kde=True)
plt.title('Churn by Tenure')
plt.show()
